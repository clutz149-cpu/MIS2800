# %% [markdown]
# <a href="https://colab.research.google.com/github/clutz149-cpu/MIS2800/blob/main/Carter_Lutyz_MIS2800_Amazon_Redshift.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Part 1: The Business Impact (Lyft Case Study)

# %% [markdown]
# **Lyft Video**: https://aws.amazon.com/solutions/case-studies/lyft/
#
# **Watch the Lyft video and consider the following:**
#
# 1. The Innovation: How did moving from simple data storage to a Redshift data warehouse allow Lyft to transition from "just tracking rides" to "creating new products" like Lyft Line?
#
#
# 2. Real-time vs. Strategic: Lyft uses different tools for their app (OLTP) than they do for their planning (OLAP). Why can't they just use the same database for both?

# %% [markdown]
# ## YOUR ANSWERS TO PART 1 BELOW

# %% [markdown]
# Question 1: Orignally Lyfts system focused on tracking transcations ie: rides, payments, and driver activity. It was just used for operational use. When using data in RedShift, Lyfy could analyze mass amounts of ride data at a scale. This data allowed for patterns to be identified and it could run queries efficently. This made lfyt move on from just rides and look at a even bigge picture. This is exactly where Lyft Line came in, this relieves on predicitive analyics and optimization.
#
#
# Question 2: OLTP vs OLAP. OLTP systems, lile Lyft handle of thousands of small fast transactions pers second. While OLAP systems like Redshift are designed for large, complex queries that scans millions of rows of data to identify trends and support descision making. If Lyft tried to run these queries on the same database as Redshift, it would slow down ride requests and lead to worse experience for customers.

# %% [markdown]
# ## Part 2: The Infrastructure (AWS Skill Builder)
#
# **Instructions**
#
#
# 1.   Create a free AWS Skill Builder account https://scribehow.com/viewer/AWS_Skillbuilder_and_Eduate__Souc1HOKQbiiJnktuVgSEQ
# 2.   Complete the "Introduction" and "Architecture" modules in AWS Skill Builder. Instructions are here: https://www.loom.com/share/530dd0536c2c44729fe9a6ed26f7f162
#
# # Answer the Questions
#
# 1. Scaling the Design: In DataCamp, we practiced Normalization. In the Redshift architecture, why is "Columnar Storage" often more important for an analyst than having perfectly normalized tables? https://docs.aws.amazon.com/redshift/latest/dg/c_columnar_storage_disk_mem_mgmnt.html
#
# 2. Speed to Insight: How does the architecture of a "Leader Node" and "Compute Nodes" change how quickly a Business Intelligence report is generated?  https://docs.aws.amazon.com/redshift/latest/dg/c_high_level_system_architecture.html

# %% [markdown]
# ## YOUR ANSWERS TO PART 2 BELOW

# %% [markdown]
# Question 1: In a Redshift data warehouse, columnar storage is more important for analysts than perfectly normalized tables because analytics workloads priortize speed of reading data. Columnar storage allows for Redshift to only read specifc cilumns of data need and perform aggregations much faster.
#
# Question 2: Redshifts architercture seperates responsibilites between a leader node and compute nodes. The leader node recies the query and creates an execution plan while the compute nodes process it. This MPP design allows large datasts to be analyzed much faster than a single node system.

# %% [markdown]
# ## Part 3: Strategic Reflection
#
# 1. The Management Perspective: As a future business leader, how does knowing the capabilities of a tool like Redshift change the questions you would ask your data team?
#
# 2. The ETL Bridge: Reflect on the ETL process. If you were a manager at an organization, why is the "Clean and Load" phase the most critical part of your BI strategy?

# %% [markdown]
# ## YOUR ANSWERS TO PART 3 BELOW

# %% [markdown]
# Question 1: As a future business leader understanding the capabilites of a tool like Redshift would change the ambition and qualitys of questions I could ask my team. Having these forward looking strategic questions prepared I can drivea competitive advantage rather than just describing something.
#
# Question 2:The Clean and Load phase of ETL is the most critical part of a BI strategy because analytics are only as good as the data quality. If data is inconsistent, duplicated poorly formatted, or incomplete, even the most powerful tools will produce misleading insights.
